# %%
fam = [1.73, 1.68, 1.71]
fam
# Out:
# [1.73, 1.68, 1.71]

# %%
type(fam)
# Out:
# list

# %%
strnum = ["zarir", 2.21, "islam", 3.14, "sakib"]
strnum
# Out:
# ['zarir', 2.21, 'islam', 3.14, 'sakib']

# %%
type(strnum)
# Out:
# list

# %%
num1 = [1, 2, 4, 6]
num2 = [6, 5, 4, 1]

sum = num1 + num2

sum
# Out:
# [1, 2, 4, 6, 6, 5, 4, 1]

# %%
num3 = [1, "sak", 4, "hab"]
num4 = [3, "fam", 5, "sak"]

sum1 = num3 + num4

sum1
# Out:
# [1, 'sak', 4, 'hab', 3, 'fam', 5, 'sak']

# %%
listoflist = [["Sakib", 82],
              ["Zarir", 83],
              ["Islam", 85]]

print(listoflist)
# Out:
# [['Sakib', 82], ['Zarir', 83], ['Islam', 85]]

# %%
listoflist[0]
# Out:
# ['Sakib', 82]

# %%
listoflist[0][1]
# Out:
# 82

# %% [markdown]
# **Change list elements**

# %%
listoflist[0] = ["Nabil", 90]

# %%
listoflist
# Out:
# [['Nabil', 90], ['Zarir', 83], ['Islam', 85]]

# %% [markdown]
# **Adding list elements**

# %%
listoflist+[["Sakib", 82]]
# Out:
# [['Nabil', 90], ['Zarir', 83], ['Islam', 85], ['Sakib', 82]]

# %%
listoflist
# Out:
# [['Nabil', 90], ['Zarir', 83], ['Islam', 85]]

# %% [markdown]
# **Delete list elements**

# %%
del listoflist[1]

# %%
listoflist
# Out:
# [['Nabil', 90], ['Islam', 85]]

# %%
x = ["a", "b", "c"]
y = x
x
# Out:
# ['a', 'b', 'c']

# %%
y
# Out:
# ['a', 'b', 'c']

# %%
y[1] = "z"

# %%
x
# Out:
# ['a', 'z', 'c']

# %%
y
# Out:
# ['a', 'z', 'c']

# %% [markdown]
# **-----------------**

# %%
d = list(x)

# %%
x
# Out:
# ['a', 'z', 'c']

# %%
d
# Out:
# ['a', 'z', 'c']

# %%
d[1] = "b"

# %%
x
# Out:
# ['a', 'z', 'c']

# %%
d
# Out:
# ['a', 'b', 'c']
