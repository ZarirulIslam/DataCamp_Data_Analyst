# %%
import numpy as np

# %%
num1 = np.array([1, 2, 3])
num2 = np.array([4, 5, 6])

sum = num1 + num2

sum
# Out:
# array([5, 7, 9])

# %%
np.array([True, 1, 2]) + np.array([3, 4, False])
# Out:
# array([4, 5, 2])
