# %%
import pandas as pd

# %%
dict = {
    "country":["Bangladesh", "Afghanistan", "UAE", "Oman", "Saudi Arabia"],
    "capital":["Dhaka", "Kabul", "Abu Dhabi", "Salalah", "Jedda"],
    "area":[8.516, 17.100, 3.286, 9.597, 1.221],
    "population":[147.570, 100.39, 150.45, 87.54, 120.45]
}

# %%
dict
# Out:
# {'country': ['Bangladesh', 'Afghanistan', 'UAE', 'Oman', 'Saudi Arabia'],
#  'capital': ['Dhaka', 'Kabul', 'Abu Dhabi', 'Salalah', 'Jedda'],
#  'area': [8.516, 17.1, 3.286, 9.597, 1.221],
#  'population': [147.57, 100.39, 150.45, 87.54, 120.45]}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#         country    capital    area  population
# 0    Bangladesh      Dhaka   8.516      147.57
# 1   Afghanistan      Kabul  17.100      100.39
# 2           UAE  Abu Dhabi   3.286      150.45
# 3          Oman    Salalah   9.597       87.54
# 4  Saudi Arabia      Jedda   1.221      120.45

# %%
df.index = ["Ban", "Afg", "UAE", "Omn", "SAE"]

# %%
df
# Out:
#           country    capital    area  population
# Ban    Bangladesh      Dhaka   8.516      147.57
# Afg   Afghanistan      Kabul  17.100      100.39
# UAE           UAE  Abu Dhabi   3.286      150.45
# Omn          Oman    Salalah   9.597       87.54
# SAE  Saudi Arabia      Jedda   1.221      120.45

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datacamp Data Science/Pythonpractise/brics.csv", index_col = 0)

# %%
df1
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
df1
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
df1["country"]
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
df1[1:4]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
df1.loc["RU"]
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object

# %%
df1.loc[["RU"]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
df1.loc[["RU", "IN", "CH"], ["capital", "country"]]
# Out:
#       capital country
# RU     Moscow  Russia
# IN  New Delhi   India
# CH    Beijing   China

# %%
df1.iloc[[1]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
df1.iloc[[1,2,3]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
df.iloc[1:4]
# Out:
#          country    capital    area  population
# Afg  Afghanistan      Kabul  17.100      100.39
# UAE          UAE  Abu Dhabi   3.286      150.45
# Omn         Oman    Salalah   9.597       87.54

# %%
df1.iloc[1:4, 0:2]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %%
df1.iloc[[1,2,3], [0,1]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %%
df1.iloc[:, [0,1]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %% [markdown]
# # **Comparison Operator**

# %%
import numpy as np

# %%
bmi = np.array([21.852, 20.975, 21.75, 24.747])
bmi
# Out:
# array([21.852, 20.975, 21.75 , 24.747])

# %%
bmi > 23
# Out:
# array([False, False, False,  True])

# %%
z = 3

if z % 2 == 0:
  print("Z is divisible by 2")
elif z % 3 == 0:
  print("Z is divisible by 3")
else:
  print("No")
# Out:
# Z is divisible by 3

# %%
df1["area"] > 8
# Out:
# BR     True
# RU     True
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
is_huge = df1["area"] > 8
df1[is_huge]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %%
data = [1,2,3,4,5]
ser = pd.Series(data)
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data1 = {"a":1, "b":2, "c":3}
ser1 = pd.Series(data1)
ser1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data2 = [10, 20, 30, 40]
index = ["a", "b", "c", "d"]
ser2 = pd.Series(data2, index=index)
ser2
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data3 = {
    "a":[10, 20, 30, 40],
    "b":["v", "f", "g", "h"],
    "c":[100, 200, 300, 400]
}
data3
# Out:
# {'a': [10, 20, 30, 40], 'b': ['v', 'f', 'g', 'h'], 'c': [100, 200, 300, 400]}

# %%
daf = pd.DataFrame(data3)
daf
# Out:
#     a  b    c
# 0  10  v  100
# 1  20  f  200
# 2  30  g  300
# 3  40  h  400

# %%
daf["d"] = [50, 60, 70, 80]
daf
# Out:
#     a  b    c   d
# 0  10  v  100  50
# 1  20  f  200  60
# 2  30  g  300  70
# 3  40  h  400  80

# %%
daf.drop("c", axis = 1, inplace=True)
daf
# Out:
#     a  b   d
# 0  10  v  50
# 1  20  f  60
# 2  30  g  70
# 3  40  h  80

# %%
df.dtypes
# Out:
# country        object
# capital        object
# area          float64
# population    float64
# dtype: object

# %%
print("Statistical Summary: \n", daf.describe())
# Out:
# Statistical Summary:
#                 a          d
# count   4.000000   4.000000
# mean   25.000000  65.000000
# std    12.909944  12.909944
# min    10.000000  50.000000
# 25%    17.500000  57.500000
# 50%    25.000000  65.000000
# 75%    32.500000  72.500000
# max    40.000000  80.000000

# %%
for val in df1:
  print(val)
# Out:
# country
# capital
# area
# population
