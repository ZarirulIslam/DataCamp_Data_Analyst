# %%
world = {"afghanistan":30.55, "albania":2.77, "algeria":39.21}
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %%
world["albania"]
# Out:
# 2.77

# %%
world["bangladesh"] = 18.89

# %%
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'bangladesh': 18.89}
