# %%
import pandas as pd

# %%
muslim = {
    'country': ['bangladesh', 'pakistan', 'egypt', 'indonesia'],
    'capital': ['dhaka', 'islamabad', 'cairo', 'jakarta'],
    'area': [0.148, 0.882, 1.001, 1.905],
    'population': [170, 240, 112, 277]
}

# %%
muslim
# Out:
# {'country': ['bangladesh', 'pakistan', 'egypt', 'indonesia'],
#  'capital': ['dhaka', 'islamabad', 'cairo', 'jakarta'],
#  'area': [0.148, 0.882, 1.001, 1.905],
#  'population': [170, 240, 112, 277]}

# %%
df = pd.DataFrame(muslim)

# %%
df
# Out:
#       country    capital   area  population
# 0  bangladesh      dhaka  0.148         170
# 1    pakistan  islamabad  0.882         240
# 2       egypt      cairo  1.001         112
# 3   indonesia    jakarta  1.905         277

# %%
area = df['area'] > 1

# %%
area
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: area, dtype: bool

# %%
df[area]
# Out:
#      country  capital   area  population
# 2      egypt    cairo  1.001         112
# 3  indonesia  jakarta  1.905         277
