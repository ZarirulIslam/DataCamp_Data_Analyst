# %%
import pandas as pd

# %%
muslim = {
    'country': ['bangladesh', 'pakistan', 'egypt', 'indonesia'],
    'capital': ['dhaka', 'islamabad', 'cairo', 'jakarta'],
    'area': [147570, 881913, 1001450, 1904569],
    'population': [170, 240, 112, 277]
}

# %%
muslim
# Out:
# {'country': ['bangladesh', 'pakistan', 'egypt', 'indonesia'],
#  'capital': ['dhaka', 'islamabad', 'cairo', 'jakarta'],
#  'area': [147570, 881913, 1001450, 1904569],
#  'population': [170, 240, 112, 277]}

# %%
type(muslim)
# Out:
# dict

# %%
df = pd.DataFrame(muslim)

# %%
df
# Out:
#       country    capital     area  population
# 0  bangladesh      dhaka   147570         170
# 1    pakistan  islamabad   881913         240
# 2       egypt      cairo  1001450         112
# 3   indonesia    jakarta  1904569         277

# %%
df.index = ['ban', 'pak', 'eg', 'indo']

# %%
df
# Out:
#          country    capital     area  population
# ban   bangladesh      dhaka   147570         170
# pak     pakistan  islamabad   881913         240
# eg         egypt      cairo  1001450         112
# indo   indonesia    jakarta  1904569         277
