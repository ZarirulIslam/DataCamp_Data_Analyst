# %%
world = {
    "afghanistan": 30.55,
    "albania": 2.77,
    "algeria": 39.21
}

# %%
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %%
type(world)
# Out:
# dict

# %%
world['afghanistan']
# Out:
# 30.55

# %%
#add data to dictionaries

world['bangladesh'] = 17

# %%
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'bangladesh': 17}

# %%
world['bangladesh'] = 18

# %%
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'bangladesh': 18}

# %%
#remove dict value

del(world['algeria'])

# %%
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'bangladesh': 18}

# %%
print('bangladesh' in world)
# Out:
# True

# %%
print('algeria' in world)
# Out:
# False

# %%
muslim = {
    'bangladesh': {'capital': 'dhaka', 'pop': 170},
    'pakistan': {'capital': 'islamabad', 'pop': 240},
    'egypt': {'capital': 'cairo', 'pop': 112},
    'turkey': {'capital': 'ankara', 'pop': 85}
}

# %%
muslim
# Out:
# {'bangladesh': {'capital': 'dhaka', 'pop': 170},
#  'pakistan': {'capital': 'islamabad', 'pop': 240},
#  'egypt': {'capital': 'cairo', 'pop': 112},
#  'turkey': {'capital': 'ankara', 'pop': 85}}

# %%
type(muslim)
# Out:
# dict

# %%
import pandas as pd

# %%
df = pd.DataFrame(muslim)

# %%
df
# Out:
#         bangladesh   pakistan  egypt  turkey
# capital      dhaka  islamabad  cairo  ankara
# pop            170        240    112      85
